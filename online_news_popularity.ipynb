# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import classification_report,accuracy_score
from sklearn import preprocessing, linear_model

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('OnlineNewsPopularity.csv')
display(data.head())
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# 0                   0.815385         4.0              2.0        1.0  ...
# 1                   0.791946         3.0              1.0        1.0  ...
# 2                   0.663866         3.0              1.0        1.0  ...
# 3                   0.665635         9.0              0.0        1.0  ...
# 4                   0.540890        19.0             19.0       20.0  ...
#
#     min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# 0                0.100000                     0.7               -0.350000
# 1                0.033333                     0.7               -0.118750
# 2                0.100000                     1.0               -0.466667
# 3                0.136364                     0.8               -0.369697
# 4                0.033333                     1.0               -0.220192
#
#     min_negative_polarity   max_negative_polarity   title_subjectivity  \
# 0                  -0.600               -0.200000             0.500000
# 1                  -0.125               -0.100000             0.000000
# 2                  -0.800               -0.133333             0.000000
# 3                  -0.600               -0.166667             0.000000
# 4                  -0.500               -0.050000             0.454545
#
#     title_sentiment_polarity   abs_title_subjectivity  \
# 0                  -0.187500                 0.000000
# 1                   0.000000                 0.500000
# 2                   0.000000                 0.500000
# 3                   0.000000                 0.500000
# 4                   0.136364                 0.045455
#
#     abs_title_sentiment_polarity   shares
# 0                       0.187500      593
# 1                       0.000000      711
# 2                       0.000000     1500
# 3                       0.000000     1200
# 4                       0.136364      505
#
# [5 rows x 61 columns]

# %%
data.shape
# Out:
# (39644, 61)

# %%
popularity_raw = data[data.keys()[-1]]
popularity_raw.describe()
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name:  shares, dtype: float64

# %%
features_data = data.drop(['url', data.keys()[1],data.keys()[-1]], axis=1)

# %% [markdown]
# ## Exploratory data analysis

# %%
columns_day = features_data.columns.values[29:36]
unpop=data[data[' shares']<1400]
pop=data[data[' shares']>=1400]
unpop_day = unpop[columns_day].sum().values
pop_day = pop[columns_day].sum().values

# %%
fig = plt.figure(figsize = (13,5))
plt.title("Number of popular/unpopular news over different days of a week", fontsize = 16)
plt.bar(np.arange(len(columns_day)), pop_day, width = 0.3, align="center", alpha=0.9, color = 'royalblue', \
        label = "popular")
plt.bar(np.arange(len(columns_day)) - 0.3, unpop_day, width = 0.3, align = "center", alpha=0.9, color = 'mediumseagreen', \
        label = "unpopular")
plt.xticks(np.arange(len(columns_day))-0.15, ('Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'))
plt.ylabel("Number of News", fontsize = 14)
#plt.xlabel("Days of week", fontsize = 14)
plt.legend(loc = 'upper right')
plt.tight_layout()
plt.savefig("days.pdf")
plt.show()

# %%
col_category = features_data.columns.values[11:17]
unpop_chan = unpop[col_category].sum().values
pop_chan = pop[col_category].sum().values

# %%
fig = plt.figure(figsize = (13,5))
plt.title("Number of popular/unpopular news over different article category", fontsize = 16)
plt.bar(np.arange(len(col_category)), pop_chan, width = 0.3, align="center", alpha=0.9, color = 'royalblue', \
        label = "popular")
plt.bar(np.arange(len(col_category)) - 0.3, unpop_chan, width = 0.3, align = "center", alpha=0.9, color = 'mediumseagreen', \
        label = "unpopular")
plt.xticks(np.arange(len(col_category))-0.15, ('Lifestyle','Entertainment','Business','Social Media','Technology','World'))
plt.ylabel("Number of News", fontsize = 14)
#plt.xlabel("Days of week", fontsize = 14)
plt.legend(loc = 'upper right')
plt.tight_layout()
plt.savefig("channel.pdf")
plt.show()

# %%
corr = features_data.corr()

# %%
corr = features_data.corr()

# %%
f = plt.figure(figsize=(19, 19))
plt.matshow(features_data.corr(), fignum=f.number)
plt.xticks(range(features_data.shape[1]), features_data.columns, fontsize=14, rotation=45)
plt.yticks(range(features_data.shape[1]), features_data, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
for i in corr.keys():
    cor_target = abs(corr[i])
    relevant_features = cor_target[cor_target>0.8]
    print(relevant_features)
# Out:
#  n_tokens_title    1.0
# Name:  n_tokens_title, dtype: float64
#  n_tokens_content    1.0
# Name:  n_tokens_content, dtype: float64
#  n_unique_tokens             1.000000
#  n_non_stop_words            0.999572
#  n_non_stop_unique_tokens    0.999852
# Name:  n_unique_tokens, dtype: float64
#  n_unique_tokens             0.999572
#  n_non_stop_words            1.000000
#  n_non_stop_unique_tokens    0.999532
# Name:  n_non_stop_words, dtype: float64
#  n_unique_tokens             0.999852
#  n_non_stop_words            0.999532
#  n_non_stop_unique_tokens    1.000000
# Name:  n_non_stop_unique_tokens, dtype: float64
#  num_hrefs    1.0
# Name:  num_hrefs, dtype: float64
#  num_self_hrefs    1.0
# Name:  num_self_hrefs, dtype: float64
#  num_imgs    1.0
# Name:  num_imgs, dtype: float64
#  num_videos    1.0
# Name:  num_videos, dtype: float64
#  average_token_length    1.0
# Name:  average_token_length, dtype: float64
#  num_keywords    1.0
# Name:  num_keywords, dtype: float64
#  data_channel_is_lifestyle    1.0
# Name:  data_channel_is_lifestyle, dtype: float64
#  data_channel_is_entertainment    1.0
# Name:  data_channel_is_entertainment, dtype: float64
#  data_channel_is_bus    1.0
# Name:  data_channel_is_bus, dtype: float64
#  data_channel_is_socmed    1.0
# Name:  data_channel_is_socmed, dtype: float64
#  data_channel_is_tech    1.0
# Name:  data_channel_is_tech, dtype: float64
#  data_channel_is_world    1.000000
#  LDA_02                   0.836618
# Name:  data_channel_is_world, dtype: float64
#  kw_min_min    1.000000
#  kw_max_max    0.857226
# Name:  kw_min_min, dtype: float64
#  kw_max_min    1.000000
#  kw_avg_min    0.940529
# Name:  kw_max_min, dtype: float64
#  kw_max_min    0.940529
#  kw_avg_min    1.000000
# Name:  kw_avg_min, dtype: float64
#  kw_min_max    1.0
# Name:  kw_min_max, dtype: float64
#  kw_min_min    0.857226
#  kw_max_max    1.000000
# Name:  kw_max_max, dtype: float64
#  kw_avg_max    1.0
# Name:  kw_avg_max, dtype: float64
#  kw_min_avg    1.0
# Name:  kw_min_avg, dtype: float64
#  kw_max_avg    1.000000
#  kw_avg_avg    0.811864
# Name:  kw_max_avg, dtype: float64
#  kw_max_avg    0.811864
#  kw_avg_avg    1.000000
# Name:  kw_avg_avg, dtype: float64
#  self_reference_min_shares     1.000000
#  self_reference_avg_sharess    0.818907
# Name:  self_reference_min_shares, dtype: float64
#  self_reference_max_shares     1.00000
#  self_reference_avg_sharess    0.85348
# Name:  self_reference_max_shares, dtype: float64
#  self_reference_min_shares     0.818907
#  self_reference_max_shares     0.853480
#  self_reference_avg_sharess    1.000000
# Name:  self_reference_avg_sharess, dtype: float64
#  weekday_is_monday    1.0
# Name:  weekday_is_monday, dtype: float64
#  weekday_is_tuesday    1.0
# Name:  weekday_is_tuesday, dtype: float64
#  weekday_is_wednesday    1.0
# Name:  weekday_is_wednesday, dtype: float64
#  weekday_is_thursday    1.0
# Name:  weekday_is_thursday, dtype: float64
#  weekday_is_friday    1.0
# Name:  weekday_is_friday, dtype: float64
#  weekday_is_saturday    1.0
# Name:  weekday_is_saturday, dtype: float64
#  weekday_is_sunday    1.0
# Name:  weekday_is_sunday, dtype: float64
#  is_weekend    1.0
# Name:  is_weekend, dtype: float64
#  LDA_00    1.0
# Name:  LDA_00, dtype: float64
#  LDA_01    1.0
# Name:  LDA_01, dtype: float64
#  data_channel_is_world    0.836618
#  LDA_02                   1.000000
# Name:  LDA_02, dtype: float64
#  LDA_03    1.0
# Name:  LDA_03, dtype: float64
#  LDA_04    1.0
# Name:  LDA_04, dtype: float64
#  global_subjectivity    1.0
# Name:  global_subjectivity, dtype: float64
#  global_sentiment_polarity    1.0
# Name:  global_sentiment_polarity, dtype: float64
#  global_rate_positive_words    1.0
# Name:  global_rate_positive_words, dtype: float64
#  global_rate_negative_words    1.0
# Name:  global_rate_negative_words, dtype: float64
#  rate_positive_words    1.0
# Name:  rate_positive_words, dtype: float64
#  rate_negative_words    1.0
# Name:  rate_negative_words, dtype: float64
#  avg_positive_polarity    1.0
# Name:  avg_positive_polarity, dtype: float64
#  min_positive_polarity    1.0
# Name:  min_positive_polarity, dtype: float64
#  max_positive_polarity    1.0
# Name:  max_positive_polarity, dtype: float64
#  avg_negative_polarity    1.0
# Name:  avg_negative_polarity, dtype: float64
#  min_negative_polarity    1.0
# Name:  min_negative_polarity, dtype: float64
#  max_negative_polarity    1.0
# Name:  max_negative_polarity, dtype: float64
#  title_subjectivity    1.0
# Name:  title_subjectivity, dtype: float64
#  title_sentiment_polarity    1.0
# Name:  title_sentiment_polarity, dtype: float64
#  abs_title_subjectivity    1.0
# Name:  abs_title_subjectivity, dtype: float64
#  abs_title_sentiment_polarity    1.0
# Name:  abs_title_sentiment_polarity, dtype: float64

# %% [markdown]
# n_unique_tokens             1.000000
#  n_non_stop_words            0.999572
#  n_non_stop_unique_tokens    0.999852
#
#  data_channel_is_world    1.000000
#  LDA_02                   0.836618
#   kw_min_min    1.000000
#  kw_max_max    0.857226
#
#  kw_max_min    0.940529
#  kw_avg_min    1.000000
#  kw_min_min
#  self_reference_min_shares     0.818907
#  self_reference_max_shares     0.853480
#  self_reference_avg_sharess    1.000000

# %%
data = pd.read_csv('olnews.csv') 
data.head()
# Out:
#    Unnamed: 0  timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0           1        731              12               219         0.663594
# 1           2        731               9               255         0.604743
# 2           3        731               9               211         0.575130
# 3           4        731               9               531         0.503788
# 4           5        731              13              1072         0.415646
#
#    n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 0               1.0                  0.815385          4               2
# 1               1.0                  0.791946          3               1
# 2               1.0                  0.663866          3               1
# 3               1.0                  0.665635          9               0
# 4               1.0                  0.540890         19              19
#
#    num_imgs  ...  min_positive_polarity  max_positive_polarity  \
# 0         1  ...               0.100000                    0.7
# 1         1  ...               0.033333                    0.7
# 2         1  ...               0.100000                    1.0
# 3         1  ...               0.136364                    0.8
# 4        20  ...               0.033333                    1.0
#
#    avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# 0              -0.350000                 -0.600              -0.200000
# 1              -0.118750                 -0.125              -0.100000
# 2              -0.466667                 -0.800              -0.133333
# 3              -0.369697                 -0.600              -0.166667
# 4              -0.220192                 -0.500              -0.050000
#
#    title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# 0            0.500000                 -0.187500                0.000000
# 1            0.000000                  0.000000                0.500000
# 2            0.000000                  0.000000                0.500000
# 3            0.000000                  0.000000                0.500000
# 4            0.454545                  0.136364                0.045455
#
#    abs_title_sentiment_polarity  shares
# 0                      0.187500     593
# 1                      0.000000     711
# 2                      0.000000    1500
# 3                      0.000000    1200
# 4                      0.136364     505
#
# [5 rows x 61 columns]

# %%
data.shape
# Out:
# (36879, 61)

# %%
data['pop'] = pd.Series(np.where(data.shares.values > 1300, 1, 0),
          data.index)
data.drop(['Unnamed: 0'],axis=1)
# Out:
#        timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0            731              12               219         0.663594
# 1            731               9               255         0.604743
# 2            731               9               211         0.575130
# 3            731               9               531         0.503788
# 4            731              13              1072         0.415646
# 5            731              10               370         0.559889
# 6            731               8               960         0.418163
# 7            731              12               989         0.433574
# 8            731              11                97         0.670103
# 9            731              10               231         0.636364
# 10           731               9              1248         0.490050
# 11           731              10               187         0.666667
# 12           731               9               274         0.609195
# 13           731               8               259         0.562753
# 14           731              12               682         0.459542
# 15           731               8               397         0.624679
# 16           731              11               103         0.689320
# 17           731              13              1248         0.390638
# 18           731               9               391         0.510256
# 19           731              11              1154         0.427305
# 20           731              11               125         0.674797
# 21           731              13               244         0.560000
# 22           731               8               266         0.572581
# 23           731               8               331         0.562691
# 24           731              12              1225         0.385452
# 25           731              10               243         0.619247
# 26           731              11               723         0.490934
# 27           731               8               708         0.482219
# 28           731              10               633         0.476038
# 29           731              14               290         0.611511
# ...          ...             ...               ...              ...
# 36849          9              12                 0         0.000000
# 36850          9               9               904         0.472158
# 36851          9              11                 0         0.000000
# 36852          9              15                 0         0.000000
# 36853          9              11               991         0.459173
# 36854          9              14               488         0.517454
# 36855          9              14               428         0.512881
# 36856          9              13               413         0.556675
# 36857          9              11              1122         0.439421
# 36858          9              14               436         0.529412
# 36859          9              12               429         0.514925
# 36860          9              13               224         0.570136
# 36861          9              12               249         0.567227
# 36862          9              14               874         0.480702
# 36863          9              14               626         0.552504
# 36864          9              13               209         0.656863
# 36865          9              12               491         0.454167
# 36866          9              13               746         0.465306
# 36867          9              15               580         0.506261
# 36868          9               9               614         0.476033
# 36869          9               9               251         0.666667
# 36870          9              13               478         0.514039
# 36871          8               8              2509         0.348878
# 36872          8              13              1629         0.425711
# 36873          8              11               223         0.653153
# 36874          8              11               346         0.529052
# 36875          8              12               328         0.696296
# 36876          8              10               442         0.516355
# 36877          8               6               682         0.539493
# 36878          8              10               157         0.701987
#
#        n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 0                   1.0                  0.815385          4               2
# 1                   1.0                  0.791946          3               1
# 2                   1.0                  0.663866          3               1
# 3                   1.0                  0.665635          9               0
# 4                   1.0                  0.540890         19              19
# 5                   1.0                  0.698198          2               2
# 6                   1.0                  0.549834         21              20
# 7                   1.0                  0.572108         20              20
# 8                   1.0                  0.836735          2               0
# 9                   1.0                  0.797101          4               1
# 10                  1.0                  0.731638         11               0
# 11                  1.0                  0.800000          7               0
# 12                  1.0                  0.707602         18               2
# 13                  1.0                  0.644444         19               3
# 14                  1.0                  0.634961         10               0
# 15                  1.0                  0.805668         11               0
# 16                  1.0                  0.806452          3               1
# 17                  1.0                  0.523388         21              19
# 18                  1.0                  0.650000          9               2
# 19                  1.0                  0.572816         20              20
# 20                  1.0                  0.797468          1               1
# 21                  1.0                  0.680272          3               2
# 22                  1.0                  0.721088          5               2
# 23                  1.0                  0.724490          5               3
# 24                  1.0                  0.508519         22              22
# 25                  1.0                  0.824427          1               1
# 26                  1.0                  0.642241         18               1
# 27                  1.0                  0.688119          8               3
# 28                  1.0                  0.579572          2               2
# 29                  1.0                  0.761905          0               0
# ...                 ...                       ...        ...             ...
# 36849               0.0                  0.000000          0               0
# 36850               1.0                  0.606822         27               2
# 36851               0.0                  0.000000          0               0
# 36852               0.0                  0.000000          0               0
# 36853               1.0                  0.618487         40               3
# 36854               1.0                  0.683502         14               9
# 36855               1.0                  0.698745          2               1
# 36856               1.0                  0.692913         11               2
# 36857               1.0                  0.635258          4               1
# 36858               1.0                  0.701681          6               6
# 36859               1.0                  0.658436          3               3
# 36860               1.0                  0.731343          7               7
# 36861               1.0                  0.748201          4               2
# 36862               1.0                  0.711538         13               1
# 36863               1.0                  0.759791          4               2
# 36864               1.0                  0.722628          4               1
# 36865               1.0                  0.609665          2               2
# 36866               1.0                  0.735849          4               1
# 36867               1.0                  0.661891         15               2
# 36868               1.0                  0.614987         10               0
# 36869               1.0                  0.786164         21              13
# 36870               1.0                  0.641844         18               2
# 36871               1.0                  0.464923         23               1
# 36872               1.0                  0.606092         15              12
# 36873               1.0                  0.825758          5               3
# 36874               1.0                  0.684783          9               7
# 36875               1.0                  0.885057          9               7
# 36876               1.0                  0.644128         24               1
# 36877               1.0                  0.692661         10               1
# 36878               1.0                  0.846154          1               1
#
#        num_imgs  num_videos  ...  max_positive_polarity  \
# 0             1           0  ...               0.700000
# 1             1           0  ...               0.700000
# 2             1           0  ...               1.000000
# 3             1           0  ...               0.800000
# 4            20           0  ...               1.000000
# 5             0           0  ...               0.600000
# 6            20           0  ...               1.000000
# 7            20           0  ...               1.000000
# 8             0           0  ...               0.800000
# 9             1           1  ...               0.500000
# 10            1           0  ...               1.000000
# 11            1           0  ...               0.700000
# 12           11           0  ...               0.700000
# 13            9           0  ...               0.500000
# 14            1           0  ...               0.600000
# 15            1           0  ...               1.000000
# 16            1           0  ...               0.500000
# 17           20           0  ...               1.000000
# 18            1           1  ...               0.350000
# 19           20           0  ...               1.000000
# 20            1           0  ...               0.600000
# 21            1           0  ...               0.433333
# 22            1           0  ...               0.350000
# 23            1           0  ...               1.000000
# 24           28           0  ...               1.000000
# 25            0           0  ...               0.600000
# 26            1           0  ...               1.000000
# 27            1           1  ...               1.000000
# 28           19           0  ...               0.600000
# 29           14           0  ...               1.000000
# ...         ...         ...  ...                    ...
# 36849        14           0  ...               0.000000
# 36850         2           0  ...               0.600000
# 36851        21           1  ...               0.000000
# 36852         0           1  ...               0.000000
# 36853         4           0  ...               1.000000
# 36854         1           0  ...               0.800000
# 36855         1           0  ...               0.700000
# 36856         1           0  ...               0.500000
# 36857         6           0  ...               1.000000
# 36858         2           0  ...               0.700000
# 36859         3           0  ...               0.750000
# 36860         1           1  ...               0.500000
# 36861         1           1  ...               1.000000
# 36862         1           0  ...               0.600000
# 36863         1           0  ...               0.800000
# 36864         0           2  ...               0.850000
# 36865         2           1  ...               0.900000
# 36866         1           0  ...               0.850000
# 36867         3           0  ...               0.800000
# 36868         1           0  ...               0.800000
# 36869         9           2  ...               1.000000
# 36870         2           0  ...               1.000000
# 36871        10           0  ...               1.000000
# 36872         6           0  ...               1.000000
# 36873         1           0  ...               0.800000
# 36874         1           1  ...               0.750000
# 36875         3          48  ...               0.700000
# 36876        12           1  ...               0.500000
# 36877         1           0  ...               0.500000
# 36878         0           2  ...               0.500000
#
#        avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# 0                  -0.350000              -0.600000              -0.200000
# 1                  -0.118750              -0.125000              -0.100000
# 2                  -0.466667              -0.800000              -0.133333
# 3                  -0.369697              -0.600000              -0.166667
# 4                  -0.220192              -0.500000              -0.050000
# 5                  -0.195000              -0.400000              -0.100000
# 6                  -0.224479              -0.500000              -0.050000
# 7                  -0.242778              -0.500000              -0.050000
# 8                  -0.125000              -0.125000              -0.125000
# 9                  -0.238095              -0.500000              -0.100000
# 10                 -0.415064              -1.000000              -0.100000
# 11                 -0.262500              -0.400000              -0.125000
# 12                 -0.310417              -0.600000              -0.050000
# 13                 -0.138690              -0.187500              -0.050000
# 14                 -0.220150              -0.600000              -0.050000
# 15                 -0.144643              -0.200000              -0.100000
# 16                 -0.125000              -0.125000              -0.125000
# 17                 -0.206548              -0.500000              -0.050000
# 18                 -0.108333              -0.166667              -0.050000
# 19                 -0.230263              -0.500000              -0.050000
# 20                  0.000000               0.000000               0.000000
# 21                 -0.456481              -1.000000              -0.125000
# 22                 -0.116667              -0.200000              -0.050000
# 23                 -0.263889              -0.500000              -0.125000
# 24                 -0.202292              -0.500000              -0.050000
# 25                 -0.177500              -0.312500              -0.125000
# 26                 -0.213889              -0.600000              -0.100000
# 27                 -0.244444              -0.500000              -0.050000
# 28                 -0.341667              -0.800000              -0.100000
# 29                 -0.177778              -0.400000              -0.008333
# ...                      ...                    ...                    ...
# 36849               0.000000               0.000000               0.000000
# 36850              -0.225694              -0.500000              -0.050000
# 36851               0.000000               0.000000               0.000000
# 36852               0.000000               0.000000               0.000000
# 36853              -0.188889              -0.500000              -0.050000
# 36854              -0.170833              -0.250000              -0.125000
# 36855              -0.271429              -0.700000              -0.100000
# 36856              -0.525000              -0.750000              -0.300000
# 36857              -0.262500              -1.000000              -0.100000
# 36858              -0.255208              -0.500000              -0.100000
# 36859              -0.179847              -0.312500              -0.025000
# 36860              -0.071429              -0.071429              -0.071429
# 36861              -0.145833              -0.166667              -0.125000
# 36862              -0.325000              -0.600000              -0.125000
# 36863              -0.558333              -1.000000              -0.100000
# 36864              -0.366667              -0.500000              -0.100000
# 36865              -0.164881              -0.333333              -0.050000
# 36866              -0.375000              -1.000000              -0.050000
# 36867              -0.115000              -0.125000              -0.100000
# 36868              -0.181313              -0.300000              -0.050000
# 36869              -0.558333              -1.000000              -0.125000
# 36870              -0.223611              -0.400000              -0.050000
# 36871              -0.231612              -0.600000              -0.050000
# 36872              -0.429534              -1.000000              -0.050000
# 36873              -0.250000              -0.250000              -0.250000
# 36874              -0.260000              -0.500000              -0.125000
# 36875              -0.211111              -0.400000              -0.100000
# 36876              -0.356439              -0.800000              -0.166667
# 36877              -0.205246              -0.500000              -0.012500
# 36878              -0.200000              -0.200000              -0.200000
#
#        title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# 0                0.500000                 -0.187500                0.000000
# 1                0.000000                  0.000000                0.500000
# 2                0.000000                  0.000000                0.500000
# 3                0.000000                  0.000000                0.500000
# 4                0.454545                  0.136364                0.045455
# 5                0.642857                  0.214286                0.142857
# 6                0.000000                  0.000000                0.500000
# 7                1.000000                  0.500000                0.500000
# 8                0.125000                  0.000000                0.375000
# 9                0.000000                  0.000000                0.500000
# 10               0.000000                  0.000000                0.500000
# 11               0.000000                  0.000000                0.500000
# 12               1.000000                 -1.000000                0.500000
# 13               0.750000                  0.550000                0.250000
# 14               0.750000                 -0.250000                0.250000
# 15               0.000000                  0.000000                0.500000
# 16               0.857143                 -0.714286                0.357143
# 17               0.000000                  0.000000                0.500000
# 18               0.000000                  0.000000                0.500000
# 19               0.000000                  0.000000                0.500000
# 20               0.450000                  0.400000                0.050000
# 21               0.700000                 -0.400000                0.200000
# 22               0.900000                  0.400000                0.400000
# 23               0.000000                  0.000000                0.500000
# 24               0.500000                  0.500000                0.000000
# 25               0.000000                  0.000000                0.500000
# 26               0.500000                  0.500000                0.000000
# 27               0.000000                  0.000000                0.500000
# 28               0.000000                  0.000000                0.500000
# 29               0.000000                  0.000000                0.500000
# ...                   ...                       ...                     ...
# 36849            0.000000                  0.000000                0.500000
# 36850            0.000000                  0.000000                0.500000
# 36851            0.454545                  0.136364                0.045455
# 36852            0.454545                  0.136364                0.045455
# 36853            0.454545                  0.136364                0.045455
# 36854            0.125000                 -0.125000                0.375000
# 36855            0.000000                  0.000000                0.500000
# 36856            0.650000                  0.000000                0.150000
# 36857            0.300000                  0.166667                0.200000
# 36858            0.850000                 -0.400000                0.350000
# 36859            0.000000                  0.000000                0.500000
# 36860            0.800000                  0.400000                0.300000
# 36861            0.000000                  0.000000                0.500000
# 36862            0.577273                 -0.131818                0.077273
# 36863            0.000000                  0.000000                0.500000
# 36864            1.000000                 -0.500000                0.500000
# 36865            0.477273                  0.168182                0.022727
# 36866            1.000000                 -1.000000                0.500000
# 36867            0.500000                  0.500000                0.000000
# 36868            0.000000                  0.000000                0.500000
# 36869            0.000000                  0.000000                0.500000
# 36870            0.100000                  0.000000                0.400000
# 36871            0.000000                  0.000000                0.500000
# 36872            0.783333                 -0.600000                0.283333
# 36873            0.000000                  0.000000                0.500000
# 36874            0.100000                  0.000000                0.400000
# 36875            0.300000                  1.000000                0.200000
# 36876            0.454545                  0.136364                0.045455
# 36877            0.000000                  0.000000                0.500000
# 36878            0.333333                  0.250000                0.166667
#
#        abs_title_sentiment_polarity  shares  pop
# 0                          0.187500     593    0
# 1                          0.000000     711    0
# 2                          0.000000    1500    1
# 3                          0.000000    1200    0
# 4                          0.136364     505    0
# 5                          0.214286     855    0
# 6                          0.000000     556    0
# 7                          0.500000     891    0
# 8                          0.000000    3600    1
# 9                          0.000000     710    0
# 10                         0.000000    2200    1
# 11                         0.000000    1900    1
# 12                         1.000000     823    0
# 13                         0.550000     761    0
# 14                         0.250000    1600    1
# 15                         0.000000    3100    1
# 16                         0.714286    5700    1
# 17                         0.000000    2800    1
# 18                         0.000000     598    0
# 19                         0.000000     445    0
# 20                         0.400000    1500    1
# 21                         0.400000     852    0
# 22                         0.400000     783    0
# 23                         0.000000    1500    1
# 24                         0.500000    1800    1
# 25                         0.000000     462    0
# 26                         0.500000     425    0
# 27                         0.000000    3200    1
# 28                         0.000000    3900    1
# 29                         0.000000     480    0
# ...                             ...     ...  ...
# 36849                      0.000000    1600    1
# 36850                      0.000000    1400    1
# 36851                      0.136364    5700    1
# 36852                      0.136364    2100    1
# 36853                      0.136364     691    0
# 36854                      0.125000    1400    1
# 36855                      0.000000    1200    0
# 36856                      0.000000    2400    1
# 36857                      0.166667    2900    1
# 36858                      0.400000     947    0
# 36859                      0.000000    3200    1
# 36860                      0.400000    1400    1
# 36861                      0.000000    1100    0
# 36862                      0.131818    1200    0
# 36863                      0.000000    1000    0
# 36864                      0.500000    2400    1
# 36865                      0.168182    1500    1
# 36866                      1.000000     914    0
# 36867                      0.500000    1700    1
# 36868                      0.000000    1500    1
# 36869                      0.000000    1000    0
# 36870                      0.000000    1300    0
# 36871                      0.000000    1700    1
# 36872                      0.600000    1400    1
# 36873                      0.000000    1200    0
# 36874                      0.000000    1800    1
# 36875                      1.000000    1900    1
# 36876                      0.136364    1900    1
# 36877                      0.000000    1100    0
# 36878                      0.250000    1300    0
#
# [36879 rows x 61 columns]

# %%
X_data = data.iloc[:,1:60]

# %%
y = data['pop']

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X_data,y, test_size=test_size, random_state=seed)

# %%
X_train.head()
# Out:
#        timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 30982        105              13               560         0.596226
# 23849        229              11              1146         0.392540
# 6792         596               9               983         0.480829
# 34069         57              13               555         0.499096
# 451          723              10               678         0.517398
#
#        n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 30982               1.0                  0.740000         30               1
# 23849               1.0                  0.555723         15               4
# 6792                1.0                  0.588064         43              10
# 34069               1.0                  0.643275          2               1
# 451                 1.0                  0.737430         15               0
#
#        num_imgs  num_videos  ...  avg_positive_polarity  \
# 30982         1           0  ...               0.223261
# 23849         5           1  ...               0.435547
# 6792         33           1  ...               0.209316
# 34069         6           1  ...               0.290342
# 451           1           0  ...               0.462601
#
#        min_positive_polarity  max_positive_polarity  avg_negative_polarity  \
# 30982               0.033333                   0.55              -0.315972
# 23849               0.100000                   1.00              -0.277056
# 6792                0.033333                   0.90              -0.197222
# 34069               0.033333                   0.60              -0.220000
# 451                 0.100000                   1.00              -0.237831
#
#        min_negative_polarity  max_negative_polarity  title_subjectivity  \
# 30982                   -1.0              -0.100000                0.00
# 23849                   -0.4              -0.050000                0.25
# 6792                    -0.5              -0.050000                0.40
# 34069                   -0.5              -0.050000                0.20
# 451                     -0.4              -0.071429                0.00
#
#        title_sentiment_polarity  abs_title_subjectivity  \
# 30982                      0.00                    0.50
# 23849                     -0.15                    0.25
# 6792                      -0.40                    0.10
# 34069                      0.20                    0.30
# 451                        0.00                    0.50
#
#        abs_title_sentiment_polarity
# 30982                          0.00
# 23849                          0.15
# 6792                           0.40
# 34069                          0.20
# 451                            0.00
#
# [5 rows x 59 columns]

# %% [markdown]
# ## Scale data

# %%
col_ex = ['data_channel_is_lifestyle',
 'data_channel_is_entertainment',
 'data_channel_is_bus',
 'data_channel_is_socmed',
 'data_channel_is_tech',
 'data_channel_is_world',
 'weekday_is_monday',
 'weekday_is_tuesday',
 'weekday_is_wednesday',
 'weekday_is_thursday',
 'weekday_is_friday',
 'weekday_is_saturday',
 'weekday_is_sunday',
 'is_weekend']

# %%
cols_to_norm = [col for col in X_train.columns if col not in col_ex]

# %%
scale_mean = X_train[cols_to_norm].mean()
scale_std = X_train[cols_to_norm].std()

# %%
X_train[cols_to_norm]=(X_train[cols_to_norm]-scale_mean)/scale_std
# Out:
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
X_test[cols_to_norm]=(X_test[cols_to_norm]-scale_mean)/scale_std

# %%
X_train.head()
# Out:
#        timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 30982  -1.163552        1.229976          0.029292         0.480936
# 23849  -0.587805        0.281007          1.280908        -1.031019
# 6792    1.116218       -0.667962          0.932762        -0.375653
# 34069  -1.386421        1.229976          0.018612        -0.240060
# 451     1.705893       -0.193477          0.281323        -0.104204
#
#        n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 30982          0.169491                  0.433116   1.765401       -0.590441
# 23849          0.169491                 -0.788832   0.396459        0.176842
# 6792           0.169491                 -0.574376   2.951819        1.711409
# 34069          0.169491                 -0.208272  -0.789959       -0.590441
# 451            0.169491                  0.416075   0.396459       -0.846202
#
#        num_imgs  num_videos  ...  avg_positive_polarity  \
# 30982 -0.415815   -0.303736  ...              -1.262520
# 23849  0.081767   -0.055966  ...               0.803818
# 6792   3.564848   -0.055966  ...              -1.398262
# 34069  0.206163   -0.055966  ...              -0.609571
# 451   -0.415815   -0.303736  ...               1.067157
#
#        min_positive_polarity  max_positive_polarity  avg_negative_polarity  \
# 30982              -0.876310              -0.838019              -0.464043
# 23849               0.061913               0.993495              -0.155217
# 6792               -0.876310               0.586492               0.478322
# 34069              -0.876310              -0.634517               0.297564
# 451                 0.061913               0.993495               0.156065
#
#        min_negative_polarity  max_negative_polarity  title_subjectivity  \
# 30982              -1.665660               0.077751           -0.868100
# 23849               0.407579               0.611277           -0.091098
# 6792                0.062039               0.611277            0.375103
# 34069               0.062039               0.611277           -0.246498
# 451                 0.407579               0.382623           -0.868100
#
#        title_sentiment_polarity  abs_title_subjectivity  \
# 30982                 -0.270157                0.839031
# 23849                 -0.841470               -0.481311
# 6792                  -1.793658               -1.273517
# 34069                  0.491593               -0.217243
# 451                   -0.270157                0.839031
#
#        abs_title_sentiment_polarity
# 30982                     -0.687706
# 23849                     -0.018327
# 6792                       1.097304
# 34069                      0.204799
# 451                       -0.687706
#
# [5 rows x 59 columns]

# %%
X_test.head()
# Out:
#        timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 18232  -0.063133        1.704461          0.319769        -0.268035
# 17370   0.025086       -0.667962          0.142492        -0.014290
# 31540  -1.205340        0.281007         -0.252643         0.347742
# 17520   0.011156       -0.667962         -0.303903         0.594525
# 27943  -0.917467        0.281007          0.484231        -0.090802
#
#        n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 18232          0.169491                 -0.378674   0.305196        0.176842
# 17370          0.169491                 -0.029457   0.761510       -0.334680
# 31540          0.169491                 -0.128598   0.213933       -0.334680
# 17520          0.169491                  0.601757  -0.242381       -0.846202
# 27943          0.169491                 -0.213119   0.305196        0.176842
#
#        num_imgs  num_videos  ...  avg_positive_polarity  \
# 18232 -0.540211    2.421733  ...               0.219877
# 17370 -0.415815   -0.055966  ...               0.405948
# 31540  0.703746   -0.303736  ...               1.451024
# 17520 -0.415815   -0.303736  ...              -0.044149
# 27943  0.828142    0.439574  ...               1.196879
#
#        min_positive_polarity  max_positive_polarity  avg_negative_polarity  \
# 18232              -0.876310               0.993495              -0.046316
# 17370               0.061913               0.179489               0.419539
# 31540               0.061913               0.993495               0.742846
# 17520               0.061913               0.179489               0.799979
# 27943               0.061913               0.993495              -0.040687
#
#        min_negative_polarity  max_negative_polarity  title_subjectivity  \
# 18232               0.062039              -0.189013            1.514707
# 17370              -0.629040               0.611277            0.530504
# 31540               0.925888               0.611277            1.100306
# 17520               0.407579               0.433435           -0.246498
# 27943              -0.283501               0.382623            2.239909
#
#        title_sentiment_polarity  abs_title_subjectivity  \
# 18232                  1.126385               -0.393289
# 17370                  0.301156               -1.537586
# 31540                  1.602479               -1.097472
# 17520                 -0.651033               -0.217243
# 27943                  3.538595                0.839031
#
#        abs_title_sentiment_polarity
# 18232                      0.948553
# 17370                     -0.018327
# 31540                      1.506368
# 17520                     -0.241454
# 27943                      3.774818
#
# [5 rows x 59 columns]

# %% [markdown]
# ## xgb

# %%
model1 = XGBClassifier()
model2 = XGBClassifier(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(X_train, y_train)
train_model2 = model2.fit(X_train, y_train)

# %%
pred1 = train_model1.predict(X_test)
pred2 = train_model2.predict(X_test)

print(classification_report(y_test, pred1))
print(classification_report(y_test, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67      6079
#            1       0.67      0.67      0.67      6092
#
#     accuracy                           0.67     12171
#    macro avg       0.67      0.67      0.67     12171
# weighted avg       0.67      0.67      0.67     12171
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.67      0.66      6079
#            1       0.66      0.65      0.66      6092
#
#     accuracy                           0.66     12171
#    macro avg       0.66      0.66      0.66     12171
# weighted avg       0.66      0.66      0.66     12171

# %%
report = classification_report(y_test, pred1,output_dict =True)

# %%
xgb_eva = pd.DataFrame(report).transpose()
xgb_eva.to_csv(r'xgb_report.csv', index = False, header=True)

# %%
from sklearn.metrics import mean_squared_error, auc
print("Accuracy for model 1: %.2f" % (accuracy_score(y_test, pred1) * 100))
print("Accuracy for model 2: %.2f" % (accuracy_score(y_test, pred2) * 100))
print("MSE : %.4f" % mean_squared_error(y_test,pred1))
# Out:
# Accuracy for model 1: 66.72
# Accuracy for model 2: 66.04
# MSE : 0.3328

# %%
feature_importance = model1.feature_importances_

feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize = (19,19))
plt.title("Feature importances")
plt.barh(pos, feature_importance[sorted_idx], align = 'center')
plt.yticks(pos,X_train.keys()[sorted_idx])
plt.savefig('XGBimportance.jpeg')
plt.show()

# %%
import scikitplot as skplt
from sklearn import metrics
probs = model1.predict_proba(X_test)
fpr, tpr, threshold = metrics.roc_curve(y_test,pred1)
roc_auc = metrics.auc(fpr,tpr)
skplt.metrics.plot_roc(y_test, probs)
plt.savefig('ROC_XG.jpeg')
plt.show()

# %%
sorted_idx
# Out:
# array([22, 18, 54, 36, 33, 14, 30, 46, 51, 32, 53,  9,  4, 10, 58,  1, 52,
#        56, 49, 31,  7, 45, 23, 47, 19, 57, 39, 55, 12, 11, 48, 43, 44, 34,
#         2, 41, 20, 28,  5, 42,  6,  8, 35, 38,  3, 21, 50, 24,  0, 40, 25,
#        27, 15, 26, 16, 37, 29, 13, 17])

# %%
feature_importance[sorted_idx]
# Out:
# array([  0.       ,   0.       ,   0.       ,   0.       ,   0.       ,
#          0.       ,   0.       ,   4.3050413,   5.2823   ,   5.4987245,
#          5.6849794,   6.0552673,   6.2435613,   6.2923965,   6.640225 ,
#          6.658635 ,   7.405718 ,   7.754533 ,   8.036912 ,   8.243855 ,
#          8.255005 ,   9.756892 ,   9.848333 ,   9.878385 ,   9.994949 ,
#         10.195421 ,  10.567842 ,  10.949828 ,  11.0028925,  12.243153 ,
#         12.269001 ,  12.556987 ,  13.227461 ,  13.684368 ,  14.243682 ,
#         14.353392 ,  14.425807 ,  14.758176 ,  14.857859 ,  16.449053 ,
#         17.360144 ,  17.68372  ,  18.814787 ,  18.927813 ,  20.713305 ,
#         22.69041  ,  22.787073 ,  23.769524 ,  24.903927 ,  26.206398 ,
#         35.30889  ,  43.85743  ,  45.807182 ,  52.514427 ,  53.44177  ,
#         55.094685 ,  56.157867 ,  99.27622  , 100.       ], dtype=float32)

# %% [markdown]
# ## Logistic Regression

# %%
clf2 = linear_model.LogisticRegression()
clf2.fit(X_train, y_train)
predicted2 = clf2.predict(X_test)
accuracy_score(predicted2, y_test)
# Out:
# 0.643825486812916

# %%
print(classification_report(y_test, predicted2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.66      0.65      6079
#            1       0.65      0.63      0.64      6092
#
#     accuracy                           0.64     12171
#    macro avg       0.64      0.64      0.64     12171
# weighted avg       0.64      0.64      0.64     12171

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Random Forest

# %%
rf=RandomForestClassifier()
model_rf=rf.fit(X_train,y_train)

# %%
pred_rf = model_rf.predict(X_test)
print(classification_report(y_test, pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.67      0.66      6079
#            1       0.66      0.65      0.66      6092
#
#     accuracy                           0.66     12171
#    macro avg       0.66      0.66      0.66     12171
# weighted avg       0.66      0.66      0.66     12171

# %%
accuracy_score(y_test, pred_rf)
# Out:
# 0.661819078136554

# %%
mean_squared_error(y_test, pred_rf)
# Out:
# 0.3381809218634459

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test,pred_rf)
roc_auc_rf = metrics.auc(fpr,tpr)
roc_auc_rf
# Out:
# 0.6618265906211679

# %%
mms=MinMaxScaler()

# %%
mms.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_mms=mms.transform(X_train)

# %%
X_test_mms=mms.transform(X_test)

# %%
model1 = XGBClassifier()
model2 = XGBClassifier(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(X_train_mms, y_train)
train_model2 = model2.fit(X_train_mms, y_train)

# %%
pred1 = train_model1.predict(X_test_mms)
pred2 = train_model2.predict(X_test_mms)

print(classification_report(y_test, pred1))
print(classification_report(y_test, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66      6079
#            1       0.66      0.66      0.66      6092
#
#     accuracy                           0.66     12171
#    macro avg       0.66      0.66      0.66     12171
# weighted avg       0.66      0.66      0.66     12171
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66      6079
#            1       0.66      0.66      0.66      6092
#
#     accuracy                           0.66     12171
#    macro avg       0.66      0.66      0.66     12171
# weighted avg       0.66      0.66      0.66     12171

# %% [markdown]
# ## grid search

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator=XGBClassifier()

# %%
parameters={
    'max_depth':range (2,10,2),
    'n_estimators':range(60,200,40),
    'learning_rate':[0.1,0.01,0.05],
    'gamma':[0,0.1,0.2]
}

# %%
grid_search=GridSearchCV(
    estimator=estimator,
    param_grid=parameters,
    scoring = 'roc_auc',
    n_jobs=-1,
    cv=3,
    verbose=True)

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 432 out of 432 | elapsed: 17.9min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='warn', n_jobs=-1,
#              param_grid={'gamma': [0, 0.1, 0.2],
#                          'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': range(2, 10, 2),
#                          'n_estimators': range(60, 200, 40)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='roc_auc', verbose=True)

# %%
predict_gs=grid_search.best_estimator_.predict(X_test)

# %%
print(classification_report(y_test, predict_gs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.67      0.67      6079
#            1       0.67      0.66      0.66      6092
#
#     accuracy                           0.66     12171
#    macro avg       0.66      0.66      0.66     12171
# weighted avg       0.66      0.66      0.66     12171

# %%
grid_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.2,
#               learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=None, n_estimators=180, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
print("Accuracy for model 1: %.2f" % (accuracy_score(y_test, predict_gs) * 100))
# Out:
# Accuracy for model 1: 66.46

# %%
a=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, gamma=0.4,
              learning_rate=0.1, max_delta_step=0, max_depth=4,
              min_child_weight=1, missing=None, n_estimators=180, n_jobs=1,
              nthread=None, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=1, verbosity=1).fit(X_train,y_train)

# %%
pred_33=a.predict(X_test)

# %%
print("Accuracy for model 1: %.2f" % (accuracy_score(y_test, pred_33) * 100))
# Out:
# Accuracy for model 1: 66.57

# %% [markdown]
# ## Neural Network

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
# Out:
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/zhijuncai/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
from sklearn.metrics import roc_curve
y_pred_keras = keras_model.predict(X_test).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)
from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

# %%
model = Sequential()
model.add(Dense(60, input_dim = 59,activation='sigmoid'))
model.add(Dense(59, activation='relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer='RMSprop',
loss='binary_crossentropy',
metrics=['accuracy'])

# %%
history=model.fit(X_train, y_train, validation_data=(X_test, y_test),
                          epochs=20,batch_size=10,verbose=1)
# Out:
# Train on 24708 samples, validate on 12171 samples
# Epoch 1/20
# 24708/24708 [==============================] - 3s 102us/step - loss: 0.6416 - accuracy: 0.6302 - val_loss: 0.6330 - val_accuracy: 0.6461
# Epoch 2/20
# 24708/24708 [==============================] - 2s 92us/step - loss: 0.6271 - accuracy: 0.6491 - val_loss: 0.6319 - val_accuracy: 0.6405
# Epoch 3/20
# 24708/24708 [==============================] - 2s 93us/step - loss: 0.6232 - accuracy: 0.6532 - val_loss: 0.6249 - val_accuracy: 0.6483
# Epoch 4/20
# 24708/24708 [==============================] - 2s 93us/step - loss: 0.6207 - accuracy: 0.6555 - val_loss: 0.6227 - val_accuracy: 0.6495
# Epoch 5/20
# 24708/24708 [==============================] - 2s 93us/step - loss: 0.6188 - accuracy: 0.6585 - val_loss: 0.6362 - val_accuracy: 0.6440
# Epoch 6/20
# 24708/24708 [==============================] - 2s 93us/step - loss: 0.6172 - accuracy: 0.6549 - val_loss: 0.6218 - val_accuracy: 0.6511
# Epoch 7/20
# 24708/24708 [==============================] - 2s 93us/step - loss: 0.6148 - accuracy: 0.6624 - val_loss: 0.6217 - val_accuracy: 0.6506
# Epoch 8/20
# 24708/24708 [==============================] - 2s 93us/step - loss: 0.6135 - accuracy: 0.6626 - val_loss: 0.6219 - val_accuracy: 0.6529
# Epoch 9/20
# 24708/24708 [==============================] - 2s 96us/step - loss: 0.6119 - accuracy: 0.6645 - val_loss: 0.6238 - val_accuracy: 0.6538
# Epoch 10/20
# 24708/24708 [==============================] - 2s 100us/step - loss: 0.6103 - accuracy: 0.6660 - val_loss: 0.6296 - val_accuracy: 0.6494
# Epoch 11/20
# 24708/24708 [==============================] - 2s 93us/step - loss: 0.6084 - accuracy: 0.6661 - val_loss: 0.6235 - val_accuracy: 0.6524
# Epoch 12/20
# 24708/24708 [==============================] - 2s 87us/step - loss: 0.6068 - accuracy: 0.6691 - val_loss: 0.6255 - val_accuracy: 0.6510
# Epoch 13/20
# 24708/24708 [==============================] - 2s 86us/step - loss: 0.6054 - accuracy: 0.6705 - val_loss: 0.6279 - val_accuracy: 0.6509
# Epoch 14/20
# 24708/24708 [==============================] - 2s 86us/step - loss: 0.6042 - accuracy: 0.6721 - val_loss: 0.6250 - val_accuracy: 0.6506
# Epoch 15/20
# 24708/24708 [==============================] - 2s 84us/step - loss: 0.6013 - accuracy: 0.6739 - val_loss: 0.6476 - val_accuracy: 0.6520
# Epoch 16/20
# 24708/24708 [==============================] - 2s 86us/step - loss: 0.6000 - accuracy: 0.6762 - val_loss: 0.6296 - val_accuracy: 0.6496
# Epoch 17/20
# 24708/24708 [==============================] - 2s 84us/step - loss: 0.5978 - accuracy: 0.6791 - val_loss: 0.6292 - val_accuracy: 0.6453
# Epoch 18/20
# 24708/24708 [==============================] - 2s 84us/step - loss: 0.5963 - accuracy: 0.6764 - val_loss: 0.6337 - val_accuracy: 0.6525
# Epoch 19/20
# 24708/24708 [==============================] - 2s 90us/step - loss: 0.5936 - accuracy: 0.6819 - val_loss: 0.6529 - val_accuracy: 0.6454
# Epoch 20/20
# 24708/24708 [==============================] - 2s 85us/step - loss: 0.5920 - accuracy: 0.6844 - val_loss: 0.6362 - val_accuracy: 0.6517

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, color='red', label='Training loss')
plt.plot(epochs, val_loss, color='green', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, color='red', label='Training acc')
plt.plot(epochs, val_acc, color='green', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
score=model.evaluate(X_test,y_test)
for i in range(len(score)):
     print("\n%s: %.2f%%" % (model.metrics_names[i], score[i]*100))
# Out:
# 12171/12171 [==============================] - 0s 11us/step
#
# loss: 63.62%
#
# accuracy: 65.17%

# %%
from sklearn.metrics import roc_curve
y_pred = model.predict(X_test).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred)

# %%
from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.title('ROC curve')
plt.show()
